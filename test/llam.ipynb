# %%
import requests

prompt = [question]

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "llama3.2:1b",
        "prompt": prompt,
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import requests
#       2
# ----> 3 prompt = question
#       4
#       5 response = requests.post(
#       6     "http://localhost:11434/api/generate",
#
# NameError: name 'question' is not defined

# %%
question = f"""
Generate SQLite SQL.

Table: sales
Columns: segment, country, product, sales, profit, date

Rules:
- Only SQL
- No explanation
- No markdown
- Use only given columns
- Use exact column names (case-sensitive)
- If unsure return: SELECT 1;

Question: {question}
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      11 - Use only given columns
#      12 - Use exact column names (case-sensitive)
#      13 - If unsure return: SELECT 1;
#      14
# ---> 15 Question: {question}
#      16 """
#
# NameError: name 'question' is not defined
