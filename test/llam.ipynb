# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Harshit Sharma\OneDrive\Desktop\New folder\Financials.csv')

# %%
schema = ", ".join(df.columns)

print(schema)
# Out:
# Segment, Country,  Product ,  Discount Band ,  Units Sold ,  Manufacturing Price ,  Sale Price ,  Gross Sales ,  Discounts ,   Sales ,  COGS ,  Profit , Date, Month Number,  Month Name , Year

# %%
print(df.info()) 
print("\nColumns:\n") 
print(df.columns)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    str
#  1   Country                700 non-null    str
#  2    Product               700 non-null    str
#  3    Discount Band         700 non-null    str
#  4    Units Sold            700 non-null    str
#  5    Manufacturing Price   700 non-null    str
#  6    Sale Price            700 non-null    str
#  7    Gross Sales           700 non-null    str
#  8    Discounts             700 non-null    str
#  9     Sales                700 non-null    str
#  10   COGS                  700 non-null    str
#  11   Profit                700 non-null    str
#  12  Date                   700 non-null    str
#  13  Month Number           700 non-null    int64
#  14   Month Name            700 non-null    str
#  15  Year                   700 non-null    int64
# dtypes: int64(2), str(14)
# memory usage: 183.7 KB
# None
#
# Columns:
#
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='str')
